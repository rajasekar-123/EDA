# %%
import pandas as pd

# %%
Iris = pd.read_csv("Iris.csv")

# %%
Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Iris.dropna(axis=1)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Iris.dropna(how='all')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Iris.dropna(subset=['SepalLengthCm'])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
Iris["SepalLengthCm"].astype("float")
# Out:
# 0      5.0
# 1      4.0
# 2      4.0
# 3      4.0
# 4      5.0
#       ...
# 145    6.0
# 146    6.0
# 147    6.0
# 148    6.0
# 149    5.0
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
Iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm      int64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
Iris["SepalLengthCm"] = Iris["SepalLengthCm"].astype("float")

# %%
Iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm      int64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
Iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
Iris.iloc[-1, -1]
# Out:
# 'Iris-virginica'

# %%
Iris.loc[100]
# Out:
# Id                          101
# SepalLengthCm               6.3
# SepalWidthCm                3.3
# PetalLengthCm               6.0
# PetalWidthCm                2.5
# Species          Iris-virginica
# Name: 100, dtype: object

# %%
Iris.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
Iris.shape
# Out:
# (150, 6)

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
Iris['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
Iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
Iris.groupby('Species')[['PetalLengthCm','PetalWidthCm']].mean()
# Out:
#                  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa              1.464         0.244
# Iris-versicolor          4.260         1.326
# Iris-virginica           5.552         2.026

# %%
Iris.shape[1]
# Out:
# 6

# %%
NewIris=Iris[['PetalLengthCm','SepalLengthCm','Species']]

# %%
NewIris
# Out:
#      PetalLengthCm  SepalLengthCm         Species
# 0              1.4            5.1     Iris-setosa
# 1              1.4            4.9     Iris-setosa
# 2              1.3            4.7     Iris-setosa
# 3              1.5            4.6     Iris-setosa
# 4              1.4            5.0     Iris-setosa
# ..             ...            ...             ...
# 145            5.2            6.7  Iris-virginica
# 146            5.0            6.3  Iris-virginica
# 147            5.2            6.5  Iris-virginica
# 148            5.4            6.2  Iris-virginica
# 149            5.1            5.9  Iris-virginica
#
# [150 rows x 3 columns]

# %%
Iris.loc[50]
# Out:
# Id                            51
# SepalLengthCm                7.0
# SepalWidthCm                 3.2
# PetalLengthCm                4.7
# PetalWidthCm                 1.4
# Species          Iris-versicolor
# Name: 50, dtype: object

# %%
Iris['Species'].value_counts().loc[['Iris-setosa']]
# Out:
# Species
# Iris-setosa    50
# Name: count, dtype: int64

# %%
Iris.loc[0:10,['PetalLengthCm','SepalLengthCm','Species']]
# Out:
#     PetalLengthCm  SepalLengthCm      Species
# 0             1.4            5.1  Iris-setosa
# 1             1.4            4.9  Iris-setosa
# 2             1.3            4.7  Iris-setosa
# 3             1.5            4.6  Iris-setosa
# 4             1.4            5.0  Iris-setosa
# 5             1.7            5.4  Iris-setosa
# 6             1.4            4.6  Iris-setosa
# 7             1.5            5.0  Iris-setosa
# 8             1.4            4.4  Iris-setosa
# 9             1.5            4.9  Iris-setosa
# 10            1.5            5.4  Iris-setosa

# %%
PetalLen = Iris[Iris['PetalLengthCm']>5]

# %%
PetalLen
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 83    84            6.0           2.7            5.1           1.6
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
Iris.iloc[75:100]
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 75   76            6.6           3.0            4.4           1.4
# 76   77            6.8           2.8            4.8           1.4
# 77   78            6.7           3.0            5.0           1.7
# 78   79            6.0           2.9            4.5           1.5
# 79   80            5.7           2.6            3.5           1.0
# 80   81            5.5           2.4            3.8           1.1
# 81   82            5.5           2.4            3.7           1.0
# 82   83            5.8           2.7            3.9           1.2
# 83   84            6.0           2.7            5.1           1.6
# 84   85            5.4           3.0            4.5           1.5
# 85   86            6.0           3.4            4.5           1.6
# 86   87            6.7           3.1            4.7           1.5
# 87   88            6.3           2.3            4.4           1.3
# ...

# %%
Virginca = Iris[(Iris['Species']=='Iris-virginica')& (Iris['PetalLengthCm']>2)]

# %%
Virginca
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
Iris[Iris['SepalLengthCm']> Iris['SepalLengthCm'].mean()]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 54    55            6.5           2.8            4.6           1.5
# 56    57            6.3           3.3            4.7           1.6
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 54   Iris-versicolor
# 56   Iris-versicolor
# ..               ...
# ...
